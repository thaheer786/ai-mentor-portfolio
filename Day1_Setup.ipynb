# %% [markdown]
# <a href="https://colab.research.google.com/github/thaheer786/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progression of skills needed for individuals and organizations to effectively leverage AI, from foundational to strategic:
#
# *   **Layer 1 & 2 (Base): Data Literacy & AI Fundamentals:** Understanding data principles, ethics, and core AI concepts like machine learning, deep learning, and algorithms.
# *   **Layer 3: AI Development & Implementation:** Practical skills in building, training, evaluating, and deploying AI models, including programming and MLOps.
# *   **Layer 4: AI Strategy & Management:** Ability to identify AI use cases, manage projects, understand ROI, and integrate AI solutions into business strategy.
# *   **Layer 5 (Top): Ethical & Societal AI:** Top-level focus on responsible AI governance, mitigating bias, assessing societal impact, and shaping future AI policies.

# %%
import os
import getpass

os.environ["GROQ_API_KEY"] = getpass.getpass(
    "Paste your Groq API key: "
)
# Out:
# Paste your Groq API key: ··········

# %%
# !pip install -q groq

# %%
from groq import Groq
import os

client = Groq(
    api_key=os.environ["GROQ_API_KEY"]
)

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "Explain the 5-Layer AI Skill Pyramid in 4 short bullet points."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# The 5-Layer AI Skill Pyramid consists of the following layers:
# * **Foundation**: Basic programming skills and understanding of mathematics and statistics.
# * **Data wrangling and visualization**: Ability to collect, clean, and visualize data for AI model training.
# * **Machine learning**: Knowledge of machine learning algorithms and techniques to build predictive models.
# * **Advanced AI and strategic implementation**: Expertise in deep learning, natural language processing, and strategic deployment of AI solutions in real-world applications.
