# %% [markdown]
# # Day 1: AI Tool Comparison Lab — 4-Tool Evaluation Matrix
#
# **Time:** 90 minutes (11:15 — 13:00)
# **Goal:** Complete 4-tool comparison matrix with concrete reasoning on three real tasks
#
# ---

# %% [markdown]
# ## Summary of Comparison Matrix
#
# ### Scoring Scale:
# - **5:** Excellent (all key criteria met, no fixes needed)
# - **3:** Good (works but requires minor fixes)
# - **1:** Poor (major issues, fabrication, or constraint violations)

# %% [markdown]
# ## 4-Tool Comparison Matrix Results
#
# ### Quick Scores (All 12 Cells Filled)
#
# | Tool | Task 1 | Task 2 | Task 3 | Overall Verdict |
# |------|--------|--------|--------|-----------------|
# | **ChatGPT** | ⭐⭐⭐⭐ (4) | ⭐⭐⭐⭐ (4) | ⭐⭐⭐⭐ (4) | **All-rounder** — Best for general tasks requiring fast, well-structured responses |
# | **Claude** | ⭐⭐⭐⭐⭐ (5) | ⭐⭐⭐⭐ (4) | ⭐⭐⭐⭐⭐ (5) | **Premium Reasoner** — Best for careful reasoning and high-stakes writing |
# | **Gemini** | ⭐⭐⭐⭐ (4) | ⭐⭐⭐ (3) | ⭐⭐⭐ (3) | **Quick Facts** — Good for numeric data; weaker on code constraints |
# | **Perplexity** | ⭐⭐⭐⭐ (4) | ⭐⭐⭐ (3) | ⭐⭐ (2) | **Research Assistant** — Best for cited sources and factual verification |

# %% [markdown]
# ## Task-by-Task Detailed Analysis
#
# ### Task 1: Summarise (25 minutes)
# **Prompt:** Summarise this article in 5 bullet points. Each bullet: maximum 15 words. Do not lose the key claims.
#
# **Results:**
# - **ChatGPT (4/5):** Clean structure, preserved 4 of 5 key claims, one bullet exceeded 15 words by 2 words
# - **Claude (5/5):** All 5 key claims preserved with nuance, perfect 15-word limit adherence, exceptional quality
# - **Gemini (4/5):** Good numeric facts preservation (60%, 35%), slightly curt style, all bullets under limit
# - **Perplexity (4/5):** Added external source citations, verified against article, inline references strengthen credibility

# %% [markdown]
# ## Detailed 12-Cell Reasoning Breakdown
#
# ### Task 1: Summarise (Article Summary in 5 bullets, max 15 words each)
#
# | Dimension | ChatGPT (4/5) | Claude (5/5) | Gemini (4/5) | Perplexity (4/5) |
# |-----------|---------------|-------------|--------------|------------------|
# | **Faithfulness to Article** | Preserved 4/5 key claims; one statistic skipped | All 5 key claims preserved with nuance | Excellent numeric facts (60%, 35%); complete coverage | Strong citations; verified all claims |
# | **Structure & Format** | Clean numbered bullets; easy to scan | Perfect parallel structure; excellent clarity | Concise, slightly curt formatting | Cited sources added; strong grounding |
# | **Word Limit (15 words max)** | One bullet exceeded by 2 words | Perfect adherence; all ≤15 words | All bullets perfectly under limit | Clean formatting; good word count |
#
# ### Task 2: Code (`score_resume_against_jd` function with standard library only)
#
# | Dimension | ChatGPT (4/5) | Claude (4/5) | Gemini (3/5) | Perplexity (3/5) |
# |-----------|---------------|-------------|--------------|------------------|
# | **Correctness** | Works on test cases; good edge case handling | Thorough; handles edge cases well | Works but less robust | Works but shorter implementation |
# | **Code Readability** | Clear variable names; good comments | Excellent comments; very readable | Clean but sometimes cryptic | Readable; decent organization |
# | **Constraint Adherence** | ✅ Standard library only; no violations | ✅ Standard library only | ❌ **VIOLATED** — Suggested sklearn instead | ✅ Standard library only |
#
# ### Task 3: Reason (Logic Puzzle: 3 students, arrival time calculation)
#
# | Dimension | ChatGPT (4/5) | Claude (5/5) | Gemini (3/5) | Perplexity (2/5) |
# |-----------|---------------|-------------|--------------|------------------|
# | **Accuracy** | ✅ Correct answer (8:10 AM, 20 min early) | ✅ Correct answer (8:10 AM, 20 min early) | ✅ Correct answer but incomplete reasoning | ❌ Treated as research, weak reasoning |
# | **Reasoning Transparency** | Clear step-by-step calculation shown | Most transparent; every step explicit | Skipped one step in timing chain | Vague; searched for similar puzzles |
# | **Confidence Calibration** | Confident, appropriate tone | Appropriately cautious; well-qualified | Confident but reasoning incomplete | Uncertain; not reasoning-focused |

# %% [markdown]
# ### Task 2: Code (25 minutes)
# **Prompt:** Write a Python function `score_resume_against_jd(resume_text, jd_text) -> dict` with standard library only.
#
# **Results:**
# - **ChatGPT (4/5):** Readable code using keyword overlap and Counter, good docstring, standard library only ✓
# - **Claude (4/5):** Thorough explanation with edge cases, slightly over-engineered but excellent readability
# - **Gemini (3/5):** Concise approach BUT suggested sklearn despite standard library constraint (violation) ✗
# - **Perplexity (3/5):** Good approach with StackOverflow citation, shorter code, less complete than others

# %% [markdown]
# ### Task 3: Reason (25 minutes)
# **Logic Puzzle:** Three students leave at 7:00, 7:30, 7:45. Third student's class starts 8:30, walk is 25 min. On time?
#
# **Correct Answer:** 8:10 AM arrival → 20 minutes early → YES, on time
#
# **Results:**
# - **ChatGPT (4/5):** Step-by-step calculation clear, correct answer (8:10 AM), well-explained with confidence
# - **Claude (5/5):** Most transparent chain-of-thought, showed every step explicitly, correct answer with appropriate caveats
# - **Gemini (3/5):** Dropped one step in timing chain, correct final answer but reasoning incomplete
# - **Perplexity (2/5):** Treated as research task rather than reasoning, weaker at pure logic problems

# %% [markdown]
# ## My 3-Sentence Verdict
#
# **I would use ChatGPT for general tasks where I need a fast, well-structured response.**
#
# **I would use Claude for long documents, careful reasoning, and high-stakes writing.**
#
# **I would use Perplexity for any factual claim I cannot afford to get wrong.**

# %% [markdown]
# ## Acceptance Checklist
#
# ✅ **Matrix with all 12 cells filled with concrete reasoning** (not 1-word scores)
# ✅ **3-sentence conclusion in Day 1 README** (documented above)
# ✅ **Pushed to public GitHub repo** (https://github.com/thaheer786/ai-mentor-portfolio)
